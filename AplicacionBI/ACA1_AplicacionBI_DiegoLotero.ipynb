# %% [markdown]
# Definir las librerias

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importar la data, utilizando dataFrame

# %%
dataSet = pd.read_csv("https://raw.githubusercontent.com/Dltr17/AnalisisExportaciones/main/AplicacionBI/ACA1-%20DiegoLotero%20-%20AplicacionBI.csv")

# %% [markdown]
# Primeras filas de datos

# %%
print("Exploracion de Datos:")
dataSet.head()
# Out:
# Exploracion de Datos:
#    FECH  ADUA  PAIS COD_PAI4  COD_SAL1 COD_SAL  DPTO2  VIA  BANDERA  REGIM  \
# 0  2304     1   249      USA         0     AXM     68    9      249      1
# 1  2304     1   580      PAN         0     AXM     68    0      580      1
# 2  2304     3    23      DEU         3     BOG      5    3      253      1
# 3  2304     3    23      DEU         3     BOG      5    9      169      1
# 4  2304     3    23      DEU         3     BOG      5    9      169      1
#
#    ...  CODUNI2  CANTI    PBK    PNK  FOBDOL       FOBPES  AGRENA FLETES  \
# 0  ...       M3    103  83301  83301  139761  634316107.0       0      0
# 1  ...       M3      9   7103   7103   10189   46390456.0       0      0
# 2  ...        U    954    142    138     363    1639910.0       0   1340
# 3  ...        U    499     68     66     190     857773.0       0    629
# 4  ...        U     60     26     26    9240   42235208.0       0      0
#
#    SEGURO  OTROSG
# 0       0       0
# ...

# %% [markdown]
# Descripción estadística

# %%
print("\nDescripción estadistica:")
dataSet.describe().T
# Out:
# Descripción estadistica:
#              count          mean           std          min           25%  \
# FECH      221175.0  2.303628e+03  1.669142e+00       2301.0  2.302000e+03
# ADUA      221175.0  3.705531e+01  2.819553e+01          1.0  3.000000e+00
# PAIS      221175.0  3.636061e+02  2.074480e+02         23.0  2.390000e+02
# COD_SAL1  221175.0  1.392993e+01  1.425955e+01          0.0  3.000000e+00
# DPTO2     221175.0  2.265171e+01  2.357006e+01          0.0  5.000000e+00
# VIA       221175.0  4.828688e+00  3.631663e+00          0.0  1.000000e+00
# BANDERA   221175.0  4.046926e+02  2.153521e+02         13.0  2.320000e+02
# REGIM     221175.0  1.016114e+00  2.472467e-01          1.0  1.000000e+00
# MODAD     221175.0  1.908974e+02  3.722953e+01          2.0  1.980000e+02
# FINALID   221175.0  1.074574e+00  2.627040e-01          1.0  1.000000e+00
# CER_ORI1  221175.0  7.308227e+00  1.920956e+00          1.0  8.000000e+00
# ...

# %% [markdown]
# Top cinco países con mayor exportaciones

# %%
top_paises = dataSet.groupby('COD_PAI4').agg({
    'FOBDOL': 'sum',          # Suma de exportaciones
    'CANTI': 'sum',           # Suma de cantidad de productos exportados
    }).sort_values(by='FOBDOL', ascending=False).head(5)

print("Top 5 países de exportación")
top_paises
# Out:
# Top 5 países de exportación
#               FOBDOL       CANTI
# COD_PAI4
# USA       6298213698  7087164785
# PAN       2103412265   594013770
# NLD       1218361330  4286833058
# CHN       1207227862  1699501605
# MEX        999020068  2676956606
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# top_paises['FOBDOL'].plot(kind='hist', bins=20, title='FOBDOL')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# top_paises['CANTI'].plot(kind='hist', bins=20, title='CANTI')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# top_paises.plot(kind='scatter', x='FOBDOL', y='CANTI', s=32, alpha=.8)
# ...

# %% [markdown]
# Gráfico de barras para visualizar los 5 países principales

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x=top_paises.index, y=top_paises['FOBDOL'], palette='viridis')
plt.title('Top 5 Países de Exportación')
plt.xlabel('Código del País')
plt.ylabel('Valor de Exportaciones (FOBDOL)')
plt.show()
# Out:
# <ipython-input-25-20f0f98274c9>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_paises.index, y=top_paises['FOBDOL'], palette='viridis')

# %% [markdown]
# Top 5 Departamentos de Exportación

# %%
top_dept = dataSet.groupby( 'COD_SAL').agg({
    'FOBDOL': 'sum',          # Suma de exportaciones
    'CANTI': 'sum',           # Suma de cantidad de productos exportados
}).sort_values(by='FOBDOL', ascending=False).head(5)

print("Top 5 Departamentos de exportación:")
print(top_dept)

plt.figure(figsize=(12, 6))
sns.barplot(x=top_dept.index, y=top_dept['FOBDOL'], palette='viridis')
plt.title('Top 5 Departamentos de Exportación')
plt.xlabel('Código de Salida')
plt.ylabel('Valor de Exportaciones (FOBDOL)')
plt.show()
# Out:
# Top 5 Departamentos de exportación:
#              FOBDOL        CANTI
# COD_SAL
# CVE      5653290081     14138920
# CTG      4117530624   4480003736
# SMR      3145040848  16068529384
# BUN      2566114134   2822976436
# BOG      1993059687   2344806498
# <ipython-input-26-25fe940ca4ec>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_dept.index, y=top_dept['FOBDOL'], palette='viridis')

# %% [markdown]
# Gráfico de Dispersión: FOBDOL en función de CANTI Septiembre

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='CANTI', y='FOBDOL', data=dataSet)
plt.title('Gráfico de Dispersión: FOBDOL en función de CANTI' )
plt.xlabel('Cantidad de Productos Exportados (CANTI)')
plt.ylabel('FOBDOL (Valor de Exportaciones en Dólares)')
plt.show()
